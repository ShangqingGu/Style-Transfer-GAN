# %%
import matplotlib.pyplot as plt
import numpy as np
#plt.rcParams.update({'axes.titlesize': 'large','axes.labelsize': 'large'})
plt.rc('xtick', labelsize=33) 
plt.rc('ytick', labelsize=33) 
font = {'weight' : 'bold',
        'size'   : 30}

plt.rc('font', **font)

# %%
stat_location_0 = "/datasets/home/home-03/84/484/yhc001/Style-Transfer-GAN/assets/Exp0-photo2vangogh/statistics/"
index = [x for x in range(0,2832,48)]
index.append(2831)

# %%
D_loss_0 = []
G_loss_0 = []
adv_0 = []
cycle_0 = []
identity_0 = []
for i in range(0,11):
    file = open(stat_location_0+str(i))
    lines = file.readlines()
    file.close()
    for x in index:
        category = lines[x].strip().split(' ')[1:]
        for p in range(len(category)):
            category[p] = category[p].split(':')[1]
        D_loss_0.append(float(category[0]))
        G_loss_0.append(float(category[1]))
        adv_0.append(float(category[2]))
        cycle_0.append(float(category[3]))
        identity_0.append(float(category[4]))

# %%
plot_index = np.array(index)/2831

# %%
test = plot_index
for x in range(1,11):
    test = np.append(test,plot_index+1*x+.00001)

# %%
test
# Out:
# array([ 0.        ,  0.01695514,  0.03391028,  0.05086542,  0.06782056,
#         0.0847757 ,  0.10173084,  0.11868598,  0.13564112,  0.15259626,
#         0.1695514 ,  0.18650653,  0.20346167,  0.22041681,  0.23737195,
#         0.25432709,  0.27128223,  0.28823737,  0.30519251,  0.32214765,
#         0.33910279,  0.35605793,  0.37301307,  0.38996821,  0.40692335,
#         0.42387849,  0.44083363,  0.45778877,  0.47474391,  0.49169905,
#         0.50865419,  0.52560933,  0.54256446,  0.5595196 ,  0.57647474,
#         0.59342988,  0.61038502,  0.62734016,  0.6442953 ,  0.66125044,
#         0.67820558,  0.69516072,  0.71211586,  0.729071  ,  0.74602614,
#         0.76298128,  0.77993642,  0.79689156,  0.8138467 ,  0.83080184,
#         0.84775698,  0.86471212,  0.88166726,  0.89862239,  0.91557753,
#         0.93253267,  0.94948781,  0.96644295,  0.98339809,  1.        ,
#         1.00001   ,  1.01696514,  1.03392028,  1.05087542,  1.06783056,
# ...

# %%
plt.figure(figsize=(20,20))
plt.plot(test,D_loss_0, label="Discriminator Loss")
plt.plot(test,G_loss_0, label="Generator Loss")
plt.plot(test,adv_0, label="Adversarial Loss")
plt.plot(test,cycle_0, label="Cycle Consistency Loss")
plt.plot(test,identity_0, label="Identity Loss")
plt.xlabel("Epoch")
plt.legend()
plt.title("Experiment 0")
#plt.ylim([0,6])
plt.xticks([x for x in range(12)])
plt.savefig('exp0.png')

# %%
stat_location_1 = "/datasets/home/home-03/84/484/yhc001/Style-Transfer-GAN/assets/Exp1-photo2vangogh/statistics/"
D_loss_1 = []
G_loss_1 = []
adv_1 = []
cycle_1 = []
identity_1 = []
lines= []
for i in range(0,11):
    file = open(stat_location_1+str(i))
    lines = file.readlines()
    file.close()
    for x in index:
        category = lines[x].strip().split(' ')[1:]
        for p in range(len(category)):
            category[p] = category[p].split(':')[1]
        D_loss_1.append(float(category[0]))
        G_loss_1.append(float(category[1]))
        adv_1.append(float(category[2]))
        cycle_1.append(float(category[3]))
        identity_1.append(float(category[4]))

# %%
plt.figure()
plt.figure(figsize=(20,20))
plt.plot(test,D_loss_1, label="Discriminator Loss")
plt.plot(test,G_loss_1, label="Generator Loss")
plt.plot(test,adv_1, label="Adversarial Loss")
plt.plot(test,cycle_1, label="Cycle Consistency Loss")
plt.plot(test,identity_1, label="Identity Loss")
plt.xlabel("Epoch")
plt.legend()
plt.title("Experiment 1")
#plt.ylim([0,6])
plt.xticks([x for x in range(12)])
plt.savefig('exp1.png')

# %%
stat_location_2 = "/datasets/home/home-03/84/484/yhc001/Style-Transfer-GAN/assets/Exp2-photo2vangogh/statistics/"
D_loss_2 = []
G_loss_2 = []
adv_2 = []
cycle_2 = []
identity_2 = []
lines= []
for i in range(0,11):
    file = open(stat_location_2+str(i))
    lines = file.readlines()
    file.close()
    for x in index:
        category = lines[x].strip().split(' ')[1:]
        for p in range(len(category)):
            category[p] = category[p].split(':')[1]
        D_loss_2.append(float(category[0]))
        G_loss_2.append(float(category[1]))
        adv_2.append(float(category[2]))
        cycle_2.append(float(category[3]))
        identity_2.append(float(category[4]))

# %%
plt.figure()
plt.figure(figsize=(20,20))
plt.plot(test,D_loss_2, label="Discriminator Loss")
plt.plot(test,G_loss_2, label="Generator Loss")
plt.plot(test,adv_2, label="Adversarial Loss")
plt.plot(test,cycle_2, label="Cycle Consistency Loss")
plt.plot(test,identity_2, label="Identity Loss")
plt.xlabel("Epoch")
plt.legend()
plt.title("Experiment 2")
#plt.ylim([0,6])
plt.xticks([x for x in range(12)])
plt.savefig('exp2.png')

# %%
plt.figure()
plt.figure(figsize=(20,20))
plt.plot(test,D_loss_0, label="Experiment 0")
plt.plot(test,D_loss_1, label="Experiment 1")
plt.plot(test,D_loss_2, label="Experiment 2")
plt.xlabel("Epoch")
plt.legend()
plt.title("Discriminator Losses")
#plt.ylim([0,6])
plt.xticks([x for x in range(12)])
plt.savefig('d_loss.png')

# %%
plt.figure()
plt.figure(figsize=(20,20))
plt.plot(test,G_loss_0, label="Experiment 0")
plt.plot(test,G_loss_1, label="Experiment 1")
plt.plot(test,G_loss_2, label="Experiment 2")

plt.xlabel("Epoch")
plt.legend()
plt.title("Generator Loss")
#plt.ylim([0,6])
plt.xticks([x for x in range(12)])
plt.savefig('g_loss.png')

# %%
plt.figure()
plt.figure(figsize=(20,20))

plt.plot(test,adv_0, label="Experiment 0")
plt.plot(test,adv_1, label="Experiment 1")
plt.plot(test,adv_2, label="Experiment 2")

plt.xlabel("Epoch")
plt.legend()
plt.title("Adversarial Loss")
#plt.ylim([0,6])
plt.xticks([x for x in range(12)])
plt.savefig('a_loss.png')

# %%
plt.figure()
plt.figure(figsize=(20,20))

plt.plot(test,cycle_0, label="Experiment 0")
plt.plot(test,cycle_1, label="Experiment 1")
plt.plot(test,cycle_2, label="Experiment 2")


plt.xlabel("Epoch")
plt.legend()
plt.title("Cycle Consistency Loss")
#plt.ylim([0,6])
plt.xticks([x for x in range(12)])
plt.savefig('c_loss.png')

# %%
plt.figure()
plt.figure(figsize=(20,20))
plt.plot(test,identity_0, label="Experiment 0")
plt.plot(test,identity_1, label="Experiment 1")
plt.plot(test,identity_2, label="Experiment 2")
plt.xlabel("Epoch")
plt.legend()
plt.title("Identity Loss")
#plt.ylim([0,6])
plt.xticks([x for x in range(12)])
plt.savefig('i_loss.png')
